# %% [markdown]
# # Exploring MNIST And Deep Neural Networks
#
# This Jupyter Notebook is a companion to [this article](), if you found this document some other way and feel you're missing some context, you might wish to read the article. The purpose of this document is to help you learn about deep neural networks and explore how changing the architecture of a neural network impacts the performance of the network.
#
# Before we can build any neural networks we need to import a few things from Keras, and prepare our data. The following code extracts the MNIST dataset, provided by Keras, and flattens the 28x28 pixel images into a vector with length 784. Additionally, it modifies the labels from a numeric value 0-9 to a one-hot encoded vector.

# %%
import keras
from keras.datasets import mnist
from keras.layers import Dense
from keras.models import Sequential

# Preparing the dataset
# Setup train and test splits
(x_train, y_train), (x_test, y_test) = mnist.load_data()

image_size = 784 # 28 x 28
x_train = x_train.reshape(x_train.shape[0], image_size) 
x_test = x_test.reshape(x_test.shape[0], image_size)

# Convert class vectors to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# ## First Network
#
# Here is a first, simple network, to solve MNIST. It has a single hidden layer with 32 nodes.

# %%
model = Sequential()

# The input layer requires the special input_shape parameter which should match
# the shape of our training data.
model.add(Dense(units=32, activation='sigmoid', input_shape=(image_size,)))
model.add(Dense(units=num_classes, activation='softmax'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_346 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_347 (Dense)            (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train & Evaluate The Network
#
# This code trains and evaluates the model we defined above.

# %%
model.compile(optimizer="sgd", loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, batch_size=128, epochs=5, verbose=True, validation_split=.1)
loss, accuracy  = model.evaluate(x_test, y_test, verbose=False)

print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/5
# 54000/54000 [==============================] - 4s 83us/step - loss: 1.5160 - acc: 0.5952 - val_loss: 1.0606 - val_acc: 0.7880
# Epoch 2/5
# 54000/54000 [==============================] - 2s 31us/step - loss: 0.9511 - acc: 0.8066 - val_loss: 0.7600 - val_acc: 0.8675
# Epoch 3/5
# 54000/54000 [==============================] - 2s 33us/step - loss: 0.7389 - acc: 0.8500 - val_loss: 0.6129 - val_acc: 0.8852
# Epoch 4/5
# 54000/54000 [==============================] - 2s 31us/step - loss: 0.6196 - acc: 0.8691 - val_loss: 0.5188 - val_acc: 0.8987
# Epoch 5/5
# 54000/54000 [==============================] - 2s 32us/step - loss: 0.5482 - acc: 0.8790 - val_loss: 0.4592 - val_acc: 0.9020
# Test loss: 0.512
# Test accuracy: 0.887

# %% [markdown]
# ## Some Helpers
#
# There are a couple of things we're going to do a lot in this notebook: build a model and evaluate that model. These two functions will save us a bit of boilerplate overall. These functions will also help us compare "apples to apples" -- since we can be sure when we call `create_dense` and `evaluate` our models and training regimen will use the same hyperparameters.
#
# Both use some of the variables declared above, and both therefore make neural networks explicitly intended for working with MNIST
#
# `create_dense` accepts an array of layer sizes, and returns a Keras model of a fully connected neural network with the layer sizes specified. `create_dense([32, 64, 128])` will return a deeply connected neural net with three hidden layers, the first with 32 nodes, second with 64 nodes, and third with 128 nodes. `create_dense` uses the `image_size` variable declared above, which means it assumes the input data will be a vector with 784 units. All the hidden layers use the sigmoid activation function except the output layer, which uses softmax.
#
# `evaluate` prints a summary of the model, trains the model, and then prints the loss and accuracy. This function always runs 5 training epochs and uses a fixed batch-size of 128 inputs per batch. It also uses the MNIST data extracted from Keras that we processed above.

# %%
def create_dense(layer_sizes):
    model = Sequential()
    model.add(Dense(layer_sizes[0], activation='sigmoid', input_shape=(image_size,)))

    for s in layer_sizes[1:]:
        model.add(Dense(units = s, activation = 'sigmoid'))

    model.add(Dense(units=num_classes, activation='softmax'))

    return model

def evaluate(model):
    model.summary()
    model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
    model.fit(x_train, y_train, batch_size=128, epochs=5, validation_split=.1, verbose=False)
    loss, accuracy  = model.evaluate(x_test, y_test, verbose=False)

    print()
    print(f'Test loss: {loss:.3}')
    print(f'Test accuracy: {accuracy:.3}')

# %% [markdown]
# ## Comparing Longer Chains
#
# The following code trains and evaluates models with different numbers of hidden layers. All the hidden layers have 32 nodes. The first model has 1 hidden layer, the second as 2 ... up to five layers.
#
# How did the longer models compare to the thinner models?

# %%
for layers in range(1, 5):
    model = create_dense([32] * layers)
    evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_378 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_379 (Dense)            (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.493
# Test accuracy: 0.89
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_380 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_381 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_382 (Dense)            (None, 10)                330
# =================================================================
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 1.19
# Test accuracy: 0.811
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_383 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_384 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_385 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_386 (Dense)            (None, 10)                330
# =================================================================
# Total params: 27,562
# Trainable params: 27,562
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.15
# Test accuracy: 0.464
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_387 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_388 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_389 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_390 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_391 (Dense)            (None, 10)                330
# =================================================================
# Total params: 28,618
# Trainable params: 28,618
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.3
# Test accuracy: 0.114

# %% [markdown]
# ## Comparing Number Of Nodes Per Layer
#
# Another way to add complexity is to add more nodes to each hidden layer. The following code creates several single layer neural networks, with increasingly more nodes in that layer.

# %%
for nodes in [32, 64, 128, 256, 512, 1024, 2048]:
    model = create_dense([nodes])
    evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_392 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_393 (Dense)            (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.502
# Test accuracy: 0.886
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_394 (Dense)            (None, 64)                50240
# _________________________________________________________________
# dense_395 (Dense)            (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.373
# Test accuracy: 0.91
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_396 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_397 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.32
# Test accuracy: 0.916
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_398 (Dense)            (None, 256)               200960
# _________________________________________________________________
# dense_399 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.274
# Test accuracy: 0.924
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_400 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_401 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.238
# Test accuracy: 0.935
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_402 (Dense)            (None, 1024)              803840
# _________________________________________________________________
# dense_403 (Dense)            (None, 10)                10250
# =================================================================
# Total params: 814,090
# Trainable params: 814,090
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.206
# Test accuracy: 0.941
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_404 (Dense)            (None, 2048)              1607680
# _________________________________________________________________
# dense_405 (Dense)            (None, 10)                20490
# =================================================================
# Total params: 1,628,170
# Trainable params: 1,628,170
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.175
# Test accuracy: 0.95

# %% [markdown]
# ## More Nodes And More Layers
#
# Now that we've looked at the number of nodes and the number of layers in an isolated context, lets look at what happens as we combine these two factors.

# %%
nodes_per_layer = 32
for layers in [1, 2, 3, 4, 5]:
    model = create_dense([nodes_per_layer] * layers)
    evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_428 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_429 (Dense)            (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.484
# Test accuracy: 0.89
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_430 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_431 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_432 (Dense)            (None, 10)                330
# =================================================================
# Total params: 26,506
# Trainable params: 26,506
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 1.34
# Test accuracy: 0.751
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_433 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_434 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_435 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_436 (Dense)            (None, 10)                330
# =================================================================
# Total params: 27,562
# Trainable params: 27,562
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.13
# Test accuracy: 0.433
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_437 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_438 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_439 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_440 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_441 (Dense)            (None, 10)                330
# =================================================================
# Total params: 28,618
# Trainable params: 28,618
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.3
# Test accuracy: 0.114
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_442 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_443 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_444 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_445 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_446 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_447 (Dense)            (None, 10)                330
# =================================================================
# Total params: 29,674
# Trainable params: 29,674
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.3
# Test accuracy: 0.114

# %%
nodes_per_layer = 128
for layers in [1, 2, 3, 4, 5]:
    model = create_dense([nodes_per_layer] * layers)
    evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_448 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_449 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.317
# Test accuracy: 0.918
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_450 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_451 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_452 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.574
# Test accuracy: 0.888
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_453 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_454 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_455 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_456 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 134,794
# Trainable params: 134,794
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 1.77
# Test accuracy: 0.544
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_457 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_458 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_459 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_460 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_461 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.28
# Test accuracy: 0.265
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_462 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_463 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_464 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_465 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_466 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_467 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 167,818
# Trainable params: 167,818
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.3
# Test accuracy: 0.114

# %%
nodes_per_layer = 512
for layers in [1, 2, 3, 4, 5]:
    model = create_dense([nodes_per_layer] * layers)
    evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_468 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_469 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.242
# Test accuracy: 0.934
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_470 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_471 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_472 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.366
# Test accuracy: 0.91
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_473 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_474 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_475 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_476 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 932,362
# Trainable params: 932,362
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 0.888
# Test accuracy: 0.822
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_477 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_478 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_479 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_480 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_481 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 1,195,018
# Trainable params: 1,195,018
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.24
# Test accuracy: 0.199
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_482 (Dense)            (None, 512)               401920
# _________________________________________________________________
# dense_483 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_484 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_485 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_486 (Dense)            (None, 512)               262656
# _________________________________________________________________
# dense_487 (Dense)            (None, 10)                5130
# =================================================================
# Total params: 1,457,674
# Trainable params: 1,457,674
# Non-trainable params: 0
# _________________________________________________________________
#
# Test loss: 2.3
# Test accuracy: 0.103

# %% [markdown]
# ## Apples To Apples Isn't Actually Fair
#
# Unfortunately, it's not so easy to just compare more complex models with the same amount of training. Often in order to increase accuracy, we have to add complexity; but in order to support that complexity we have to increase the training time.
#
# The `new_evaluate` function below supports this -- we can repeatedly call `new_evaluate` with the same model to continue training the model from where we left off.

# %%
def new_evaluate(model):
    model.fit(x_train, y_train, batch_size=128, epochs=5, validation_split=.1, verbose=False)
    loss, accuracy  = model.evaluate(x_test, y_test, verbose=False)
    print(f'Test loss: {loss:.3}')
    print(f'Test accuracy: {accuracy:.3}')
    print()

# %%
nodes_per_layer = 32
for layers in [3, 4, 5]:
    model = create_dense([nodes_per_layer] * layers)
    model.summary()
    model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
    for i in range(5):
        print("Round ", i)
        new_evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_512 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_513 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_514 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_515 (Dense)            (None, 10)                330
# =================================================================
# Total params: 27,562
# Trainable params: 27,562
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.11
# Test accuracy: 0.359
#
# Round  1
# Test loss: 1.77
# Test accuracy: 0.613
#
# Round  2
# Test loss: 1.27
# Test accuracy: 0.744
#
# Round  3
# Test loss: 0.867
# Test accuracy: 0.802
#
# Round  4
# Test loss: 0.689
# Test accuracy: 0.836
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_516 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_517 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_518 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_519 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_520 (Dense)            (None, 10)                330
# =================================================================
# Total params: 28,618
# Trainable params: 28,618
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.29
# Test accuracy: 0.114
#
# Round  1
# Test loss: 2.28
# Test accuracy: 0.114
#
# Round  2
# Test loss: 2.23
# Test accuracy: 0.209
#
# Round  3
# Test loss: 2.04
# Test accuracy: 0.239
#
# Round  4
# Test loss: 1.77
# Test accuracy: 0.36
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_521 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_522 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_523 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_524 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_525 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_526 (Dense)            (None, 10)                330
# =================================================================
# Total params: 29,674
# Trainable params: 29,674
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  1
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  2
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  3
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  4
# Test loss: 2.3
# Test accuracy: 0.114

# %%
nodes_per_layer = 128
for layers in [3, 4, 5]:
    model = create_dense([nodes_per_layer] * layers)
    model.summary()
    model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
    for i in range(5):
        print("Round ", i)
        new_evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_527 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_528 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_529 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_530 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 134,794
# Trainable params: 134,794
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 1.72
# Test accuracy: 0.595
#
# Round  1
# Test loss: 0.922
# Test accuracy: 0.83
#
# Round  2
# Test loss: 0.516
# Test accuracy: 0.887
#
# Round  3
# Test loss: 0.377
# Test accuracy: 0.908
#
# Round  4
# Test loss: 0.311
# Test accuracy: 0.919
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_531 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_532 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_533 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_534 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_535 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.28
# Test accuracy: 0.114
#
# Round  1
# Test loss: 2.22
# Test accuracy: 0.374
#
# Round  2
# Test loss: 1.87
# Test accuracy: 0.426
#
# Round  3
# Test loss: 1.27
# Test accuracy: 0.66
#
# Round  4
# Test loss: 0.867
# Test accuracy: 0.794
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_536 (Dense)            (None, 128)               100480
# _________________________________________________________________
# dense_537 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_538 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_539 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_540 (Dense)            (None, 128)               16512
# _________________________________________________________________
# dense_541 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 167,818
# Trainable params: 167,818
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  1
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  2
# Test loss: 2.3
# Test accuracy: 0.204
#
# Round  3
# Test loss: 2.3
# Test accuracy: 0.103
#
# Round  4
# Test loss: 2.29
# Test accuracy: 0.114

# %%
nodes_per_layer = 256
for layers in [3, 4, 5]:
    model = create_dense([nodes_per_layer] * layers)
    model.summary()
    model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
    for i in range(5):
        print("Round ", i)
        new_evaluate(model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_542 (Dense)            (None, 256)               200960
# _________________________________________________________________
# dense_543 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_544 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_545 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 335,114
# Trainable params: 335,114
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 1.25
# Test accuracy: 0.739
#
# Round  1
# Test loss: 0.555
# Test accuracy: 0.876
#
# Round  2
# Test loss: 0.374
# Test accuracy: 0.905
#
# Round  3
# Test loss: 0.304
# Test accuracy: 0.919
#
# Round  4
# Test loss: 0.267
# Test accuracy: 0.928
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_546 (Dense)            (None, 256)               200960
# _________________________________________________________________
# dense_547 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_548 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_549 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_550 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 400,906
# Trainable params: 400,906
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.27
# Test accuracy: 0.119
#
# Round  1
# Test loss: 2.04
# Test accuracy: 0.393
#
# Round  2
# Test loss: 1.24
# Test accuracy: 0.635
#
# Round  3
# Test loss: 0.818
# Test accuracy: 0.81
#
# Round  4
# Test loss: 0.544
# Test accuracy: 0.873
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_551 (Dense)            (None, 256)               200960
# _________________________________________________________________
# dense_552 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_553 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_554 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_555 (Dense)            (None, 256)               65792
# _________________________________________________________________
# dense_556 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 466,698
# Trainable params: 466,698
# Non-trainable params: 0
# _________________________________________________________________
# Round  0
# Test loss: 2.3
# Test accuracy: 0.105
#
# Round  1
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  2
# Test loss: 2.3
# Test accuracy: 0.114
#
# Round  3
# Test loss: 2.29
# Test accuracy: 0.114
#
# Round  4
# Test loss: 2.28
# Test accuracy: 0.114

# %% [markdown]
# ## Forcing The Thing To Learn!
#
# If you're really committed to a model, you can always try training it a *lot longer* and find out what happens. Below I reduce the batch size and dramatically increase the number of training epochs, which results in many more updates to the weights. Eventually ... it learns!

# %%
model = create_dense([32] * 5)
model.summary()
model.compile(optimizer='sgd', loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=16, epochs=30, validation_split=.1, verbose=True)
loss, accuracy  = model.evaluate(x_test, y_test, verbose=False)
print(f'Test loss: {loss:.3}')
print(f'Test accuracy: {accuracy:.3}')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_557 (Dense)            (None, 32)                25120
# _________________________________________________________________
# dense_558 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_559 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_560 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_561 (Dense)            (None, 32)                1056
# _________________________________________________________________
# dense_562 (Dense)            (None, 10)                330
# =================================================================
# Total params: 29,674
# Trainable params: 29,674
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/30
# 54000/54000 [==============================] - 16s 302us/step - loss: 2.3060 - acc: 0.1110 - val_loss: 2.3016 - val_acc: 0.1050
# Epoch 2/30
# 54000/54000 [==============================] - 12s 230us/step - loss: 2.3013 - acc: 0.1135 - val_loss: 2.3000 - val_acc: 0.1113
# Epoch 3/30
# 54000/54000 [==============================] - 12s 215us/step - loss: 2.3003 - acc: 0.1127 - val_loss: 2.3009 - val_acc: 0.1050
# Epoch 4/30
# 54000/54000 [==============================] - 12s 226us/step - loss: 2.2991 - acc: 0.1150 - val_loss: 2.2993 - val_acc: 0.1050
# Epoch 5/30
# 54000/54000 [==============================] - 10s 194us/step - loss: 2.2968 - acc: 0.1179 - val_loss: 2.2966 - val_acc: 0.2655
# Epoch 6/30
# 54000/54000 [==============================] - 10s 192us/step - loss: 2.2934 - acc: 0.1243 - val_loss: 2.2899 - val_acc: 0.1050
# Epoch 7/30
# 54000/54000 [==============================] - 10s 190us/step - loss: 2.2846 - acc: 0.1409 - val_loss: 2.2757 - val_acc: 0.1050
# Epoch 8/30
# 54000/54000 [==============================] - 12s 216us/step - loss: 2.2475 - acc: 0.2020 - val_loss: 2.1865 - val_acc: 0.2250
# Epoch 9/30
# 54000/54000 [==============================] - 12s 231us/step - loss: 2.0032 - acc: 0.2652 - val_loss: 1.8014 - val_acc: 0.3317
# Epoch 10/30
# 54000/54000 [==============================] - 12s 230us/step - loss: 1.7230 - acc: 0.3682 - val_loss: 1.6291 - val_acc: 0.3980
# Epoch 11/30
# 54000/54000 [==============================] - 16s 303us/step - loss: 1.5968 - acc: 0.4340 - val_loss: 1.5370 - val_acc: 0.4808
# Epoch 12/30
# 54000/54000 [==============================] - 17s 319us/step - loss: 1.4182 - acc: 0.5189 - val_loss: 1.2756 - val_acc: 0.5563
# Epoch 13/30
# 54000/54000 [==============================] - 13s 233us/step - loss: 1.2143 - acc: 0.5831 - val_loss: 1.1140 - val_acc: 0.6562
# Epoch 14/30
# 54000/54000 [==============================] - 12s 213us/step - loss: 1.1092 - acc: 0.6268 - val_loss: 0.9990 - val_acc: 0.6608
# Epoch 15/30
# 54000/54000 [==============================] - 18s 330us/step - loss: 1.0672 - acc: 0.6447 - val_loss: 0.9994 - val_acc: 0.6713
# Epoch 16/30
# 54000/54000 [==============================] - 17s 314us/step - loss: 1.0623 - acc: 0.6411 - val_loss: 0.9872 - val_acc: 0.6705
# Epoch 17/30
# 54000/54000 [==============================] - 13s 241us/step - loss: 0.9726 - acc: 0.6814 - val_loss: 0.8666 - val_acc: 0.7332
# Epoch 18/30
# 54000/54000 [==============================] - 12s 226us/step - loss: 0.9398 - acc: 0.7006 - val_loss: 0.9313 - val_acc: 0.7022
# Epoch 19/30
# 54000/54000 [==============================] - 11s 204us/step - loss: 0.9793 - acc: 0.6839 - val_loss: 0.8556 - val_acc: 0.7157
# Epoch 20/30
# 54000/54000 [==============================] - 10s 184us/step - loss: 0.9485 - acc: 0.6850 - val_loss: 0.9231 - val_acc: 0.6978
# Epoch 21/30
# 54000/54000 [==============================] - 10s 178us/step - loss: 0.9015 - acc: 0.7214 - val_loss: 0.8214 - val_acc: 0.7813
# Epoch 22/30
# 54000/54000 [==============================] - 9s 175us/step - loss: 0.9056 - acc: 0.7248 - val_loss: 0.8903 - val_acc: 0.7245
# Epoch 23/30
# 54000/54000 [==============================] - 10s 181us/step - loss: 0.9579 - acc: 0.6805 - val_loss: 0.8783 - val_acc: 0.7190
# Epoch 24/30
# 54000/54000 [==============================] - 10s 177us/step - loss: 0.8668 - acc: 0.7298 - val_loss: 0.7743 - val_acc: 0.7685
# Epoch 25/30
# 54000/54000 [==============================] - 9s 175us/step - loss: 0.8390 - acc: 0.7407 - val_loss: 0.7292 - val_acc: 0.7868
# Epoch 26/30
# 54000/54000 [==============================] - 10s 177us/step - loss: 0.8247 - acc: 0.7531 - val_loss: 0.7585 - val_acc: 0.7622
# Epoch 27/30
# 54000/54000 [==============================] - 9s 172us/step - loss: 0.8039 - acc: 0.7624 - val_loss: 0.7125 - val_acc: 0.7980
# Epoch 28/30
# 54000/54000 [==============================] - 9s 172us/step - loss: 0.8122 - acc: 0.7555 - val_loss: 0.7494 - val_acc: 0.7637
# Epoch 29/30
# 54000/54000 [==============================] - 9s 174us/step - loss: 0.7774 - acc: 0.7741 - val_loss: 0.7131 - val_acc: 0.7985
# Epoch 30/30
# 54000/54000 [==============================] - 9s 175us/step - loss: 0.7792 - acc: 0.7760 - val_loss: 0.7123 - val_acc: 0.8112
# Test loss: 0.761
# Test accuracy: 0.786
